# %%
import cv2,os,math
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt
from tqdm import tqdm_notebook as tqdm

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score,precision_score,accuracy_score,roc_curve
import torch
import torch.nn as nn
from torchvision import transforms
from torchvision import datasets
import torchvision.models as models
from pytorch_grad_cam.utils.image import show_cam_on_image

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("torch.device(cuda)")
    print("torch.cuda.device_count(): ", torch.cuda.device_count())
    for i in range(torch.cuda.device_count()):
        print(torch.cuda.get_device_name())
    print("torch.cuda.current_device()", torch.cuda.current_device())
else:
    device = torch.device("cpu")
    print("torch.device(cpu)")
# Out:
# torch.device(cuda)
# torch.cuda.device_count():  4
# Tesla V100-SXM2-16GB
# Tesla V100-SXM2-16GB
# Tesla V100-SXM2-16GB
# Tesla V100-SXM2-16GB
# torch.cuda.current_device() 0

# %% [markdown]
# # 1. Read data

# %%
# Data(x)
untreaded_train=np.load("../Classification/results2022/untreaded_train.npy",allow_pickle=True)
# untreaded_train=np.load("../Classification/results2022/untreaded_train_all.npy",allow_pickle=True)[:10000]
VPAtreaded_train=np.load("../Classification/results2022/VPAtreaded_train.npy",allow_pickle=True)
untreaded_test=np.load("../Classification/results2022/untreaded_test.npy",allow_pickle=True)
VPAtreaded_test=np.load("../Classification/results2022/VPAtreaded_test.npy",allow_pickle=True)

print("untreaded_train.shape:", untreaded_train.shape)
print("VPAtreaded_train.shape:", VPAtreaded_train.shape)
print("untreaded_test.shape:", untreaded_test.shape)
print("VPAtreaded_test.shape:", VPAtreaded_test.shape)

# Label(y)
y_untreaded_train = np.zeros(len(untreaded_train), dtype=np.int32)
y_VPAtreaded_train = np.ones(len(VPAtreaded_train), dtype=np.int32)

y_untreaded_test = np.zeros(len(untreaded_test), dtype=np.int32)
y_VPAtreaded_test = np.ones(len(VPAtreaded_test), dtype=np.int32)

# concatenate x and y
X_train, X_test = np.concatenate((untreaded_train, VPAtreaded_train), axis = 0), np.concatenate((untreaded_test, VPAtreaded_test), axis = 0)
y_train, y_test = np.concatenate((y_untreaded_train, y_VPAtreaded_train), axis = 0), np.concatenate((y_untreaded_test, y_VPAtreaded_test), axis = 0)
# Out:
# untreaded_train.shape: (3000, 100, 100, 3)
# VPAtreaded_train.shape: (3000, 100, 100, 3)
# untreaded_test.shape: (210, 100, 100, 3)
# VPAtreaded_test.shape: (210, 100, 100, 3)

# %% [markdown]
# # 2. Data processing

# %%
class cell_dataset(torch.utils.data.Dataset):
    def __init__(self, x, y):
        self.x = x
        self.y = y
        self.transform = transforms.ToTensor()
    def __len__(self):
        return len(self.x)
    def __getitem__(self, idx):
        return self.transform(self.x[idx]), torch.tensor(self.y[idx], dtype=torch.long)

# trainval_data = cell_dataset(X_train, y_train)
train_data = cell_dataset(X_train, y_train)
val_data = cell_dataset(X_test, y_test)

batch_size = 32
# val_size = int(len(trainval_data)*0.2)
# train_size = len(trainval_data) - val_size

# train_data, val_data = torch.utils.data.random_split(trainval_data, [train_size, val_size])
dataloader_train = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True)
dataloader_valid = torch.utils.data.DataLoader(val_data, batch_size=batch_size, shuffle=True)

# %%
train_data_01 = 0
train_size = len(train_data)
for i in range(train_size):
    train_data_01+=train_data[i][1].item()
print("Total number of train : ", train_size)
print("train_class_0: ", train_size-train_data_01)
print("train_class_1: ", train_data_01)

val_data_01 = 0
val_size = len(val_data)
for i in range(val_size):
    val_data_01+=val_data[i][1].item()
print("\nTotal number of val : ", val_size)
print("val_class_0: ", val_size-val_data_01)
print("val_class_1: ", val_data_01)

test_00 = y_test.tolist().count(0)
test_01 = y_test.tolist().count(1)
print("\nTotal number of test : ", len(y_test))
print("test_class_0 num : ", test_00)
print("test_class_1 num : ", test_01)
# Out:
# Total number of train :  6000
# train_class_0:  3000
# train_class_1:  3000
#
# Total number of val :  420
# val_class_0:  210
# val_class_1:  210
#
# Total number of test :  420
# test_class_0 num :  210
# test_class_1 num :  210

# %% [markdown]
# # 3. Build Model

# %% [markdown]
# ## 3.1 maskFCN

# %%
# resnet = torch.load("../Classification/model/SelfResnet9C1F_220920.pkl")

# %%
class ResidualBlock(nn.Module):
    def __init__(self, input_channel):
        super(ResidualBlock,self).__init__()
        self.residualblock = nn.Sequential(
            nn.Conv2d(input_channel,input_channel,kernel_size=3,stride=1,padding=1),
            nn.BatchNorm2d(input_channel),
            nn.ReLU(),
            nn.Conv2d(input_channel,input_channel,kernel_size=3,stride=1,padding=1),
            nn.BatchNorm2d(input_channel),
            nn.ReLU(),
            nn.Conv2d(input_channel,input_channel,kernel_size=3,stride=1,padding=1),
            nn.BatchNorm2d(input_channel),
        )
    def forward(self, x):
        residual = self.residualblock(x)
        return x + residual

class DownsampleBlock(nn.Module):
    def __init__(self, input_channel):
        super(DownsampleBlock,self).__init__()
        self.DownsampleBlock = nn.Sequential(
            nn.Conv2d(input_channel,input_channel,kernel_size=3,stride=2,padding=0),
            nn.BatchNorm2d(input_channel),
        )
    def forward(self, x):
        output = self.DownsampleBlock(x)
        return output

# %%
class Maskblock(nn.Module):
    def __init__(self, in_channel):
        super(Maskblock,self).__init__()
        self.Maskblock = nn.Sequential(
            nn.Conv2d(in_channel,1,kernel_size=1),
            nn.BatchNorm2d(1),
            nn.ReLU(),
        )
    def forward(self, x):
        mask = self.Maskblock(x)
        return mask
    
class Fcblock(nn.Module):
    def __init__(self):
        super(Fcblock,self).__init__()
        self.Fcblock = nn.Sequential(
            nn.AdaptiveAvgPool2d((10)),
            nn.Flatten(),
            nn.Linear(10*10*3, 2),
        )
    def forward(self, x):
        x = self.Fcblock(x)
        return x

# %%
class maskFCN(nn.Module):
    def __init__(self):
        super(maskFCN,self).__init__()
        self.pre_layer = nn.Sequential(
            nn.Conv2d(3,64,kernel_size=3,stride=1,padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU()
        )
        self.residual_layer = nn.Sequential(
            ResidualBlock(64),
#             DownsampleBlock(64),
            ResidualBlock(64),
#             DownsampleBlock(64),
            ResidualBlock(64),
        )
        self.mask_layer = Maskblock(64)
#         self.fc_layer = Fcblock()
        resnet = models.resnet18(pretrained=True)
        resnet.layer3 = nn.Sequential()
        resnet.layer4 = nn.Sequential()
        resnet.fc = nn.Linear(128, 2)
        self.fc_layer = resnet
        
    def forward(self, input_image):
        x = self.pre_layer(input_image)
        x = self.residual_layer(x)
        mask = self.mask_layer(x)
        thre = (input_image>0).float()
        mask = torch.multiply(mask, thre)
        x = torch.multiply(mask, input_image)
        output = self.fc_layer(x)
        return mask, output

# %% [markdown]
# ## 3.2 setting

# %%
model = maskFCN().to(device)

# %%
# model = torch.load("Feactor.pkl")

# #Freeze model weights
# for param in model.parameters():
#     param.requires_grad = True
# for param in model.fc.parameters():
#     param.requires_grad = True

# %%
ngpu = 4
if (device.type == 'cuda') and (ngpu > 1):
    model = nn.DataParallel(model, list(range(ngpu)))

# %%
image_size = 100
# test_input = torch.ones(1,3,image_size,image_size).to(device)
test_input = train_data[i][0].unsqueeze(0).to(device)
mask, y = model(test_input)
print(y.size())
print(mask.shape)
plt.imshow(mask[0].detach().cpu().permute(1,2,0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([1, 2])
# torch.Size([1, 3, 100, 100])

# %% [markdown]
# # 4. Train

# %%
model.avgpool = nn.AdaptiveAvgPool2d(1)
loss_function = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=0.1)  # 定义优化器
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.99) # 定义衰减策略

# %%
losstrain=[]
lossvalid=[]
Accuracytrain=[]
Accuracyvalid=[]
masklist=[]

# %%
n_epochs = 100
for epoch in range(n_epochs):
    losses_train = []
    losses_valid = []
    # Train
    optimizer.step()
    model.train()
    n_train = 0
    acc_train = 0
    for x, y in dataloader_train:
        n_train += y.size()[0]
        model.zero_grad()  # 勾配の初期化
        x = x.to(device)  # テンソルをGPUに移動
        y = y.to(device)
        mask,output = model.forward(x)  # 順伝播
        loss = loss_function(output, y)  # 誤差(クロスエントロピー誤差関数)の計算
        loss.backward()  # 誤差の逆伝播
        optimizer.step()  # パラメータの更新
        pred = output.argmax(1)  # 最大値を取るラベルを予測ラベルとする
        acc_train += (pred == y).float().sum().item()
        losses_train.append(loss.tolist())
    # Evaluate
    model.eval()
    n_val = 0
    acc_val = 0
    for x, y in dataloader_valid:
        n_val += y.size()[0]
        x = x.to(device)  # テンソルをGPUに移動
        y = y.to(device)
        mask,output = model.forward(x)  # 順伝播
        loss = loss_function(output, y)  # 誤差(クロスエントロピー誤差関数)の計算
        pred = output.argmax(1)  # 最大値を取るラベルを予測ラベルとする
        acc_val += (pred == y).float().sum().item()
        losses_valid.append(loss.tolist())
    scheduler.step()
    # Visualize loss & accuracy    
    losstrain.append(np.mean(losses_train))
    Accuracytrain.append(acc_train/n_train)
    lossvalid.append(np.mean(losses_valid))
    Accuracyvalid.append(acc_val/n_val)
    print('EPOCH: {}, Train [Loss: {:.3f}, Accuracy: {:.3f}], Valid [Loss: {:.3f}, Accuracy: {:.3f}]'
          .format(epoch,np.mean(losses_train),acc_train/n_train,np.mean(losses_valid),acc_val/n_val))
    if epoch%10==0:
        masklist.append(mask)
# Out:
# EPOCH: 0, Train [Loss: 0.588, Accuracy: 0.716], Valid [Loss: 0.683, Accuracy: 0.724]
# EPOCH: 1, Train [Loss: 0.555, Accuracy: 0.732], Valid [Loss: 2.268, Accuracy: 0.586]
# EPOCH: 2, Train [Loss: 0.545, Accuracy: 0.734], Valid [Loss: 0.587, Accuracy: 0.714]
# EPOCH: 3, Train [Loss: 0.544, Accuracy: 0.728], Valid [Loss: 0.688, Accuracy: 0.493]
# EPOCH: 4, Train [Loss: 0.517, Accuracy: 0.749], Valid [Loss: 0.828, Accuracy: 0.700]
# EPOCH: 5, Train [Loss: 0.490, Accuracy: 0.771], Valid [Loss: 0.951, Accuracy: 0.505]
# EPOCH: 6, Train [Loss: 0.469, Accuracy: 0.777], Valid [Loss: 0.470, Accuracy: 0.805]
# EPOCH: 7, Train [Loss: 0.471, Accuracy: 0.777], Valid [Loss: 0.674, Accuracy: 0.719]
# EPOCH: 8, Train [Loss: 0.467, Accuracy: 0.773], Valid [Loss: 0.693, Accuracy: 0.567]
# EPOCH: 9, Train [Loss: 0.467, Accuracy: 0.784], Valid [Loss: 0.473, Accuracy: 0.776]
# EPOCH: 10, Train [Loss: 0.461, Accuracy: 0.782], Valid [Loss: 0.655, Accuracy: 0.712]
# EPOCH: 11, Train [Loss: 0.454, Accuracy: 0.785], Valid [Loss: 0.453, Accuracy: 0.788]
# EPOCH: 12, Train [Loss: 0.442, Accuracy: 0.799], Valid [Loss: 0.749, Accuracy: 0.671]
# EPOCH: 13, Train [Loss: 0.444, Accuracy: 0.791], Valid [Loss: 0.656, Accuracy: 0.757]
# EPOCH: 14, Train [Loss: 0.463, Accuracy: 0.784], Valid [Loss: 0.802, Accuracy: 0.510]
# EPOCH: 15, Train [Loss: 0.446, Accuracy: 0.787], Valid [Loss: 0.397, Accuracy: 0.812]
# EPOCH: 16, Train [Loss: 0.453, Accuracy: 0.788], Valid [Loss: 1.086, Accuracy: 0.507]
# EPOCH: 17, Train [Loss: 0.441, Accuracy: 0.795], Valid [Loss: 0.883, Accuracy: 0.557]
# EPOCH: 18, Train [Loss: 0.428, Accuracy: 0.798], Valid [Loss: 0.634, Accuracy: 0.762]
# EPOCH: 19, Train [Loss: 0.447, Accuracy: 0.793], Valid [Loss: 2.198, Accuracy: 0.543]
# EPOCH: 20, Train [Loss: 0.448, Accuracy: 0.793], Valid [Loss: 0.677, Accuracy: 0.605]
# EPOCH: 21, Train [Loss: 0.441, Accuracy: 0.796], Valid [Loss: 0.379, Accuracy: 0.814]
# EPOCH: 22, Train [Loss: 0.432, Accuracy: 0.796], Valid [Loss: 2.070, Accuracy: 0.505]
# EPOCH: 23, Train [Loss: 0.438, Accuracy: 0.797], Valid [Loss: 0.444, Accuracy: 0.800]
# EPOCH: 24, Train [Loss: 0.427, Accuracy: 0.801], Valid [Loss: 1.526, Accuracy: 0.562]
# EPOCH: 25, Train [Loss: 0.415, Accuracy: 0.814], Valid [Loss: 0.557, Accuracy: 0.743]
# EPOCH: 26, Train [Loss: 0.425, Accuracy: 0.802], Valid [Loss: 0.552, Accuracy: 0.788]
# EPOCH: 27, Train [Loss: 0.417, Accuracy: 0.809], Valid [Loss: 0.483, Accuracy: 0.807]
# EPOCH: 28, Train [Loss: 0.408, Accuracy: 0.815], Valid [Loss: 0.983, Accuracy: 0.595]
# EPOCH: 29, Train [Loss: 0.412, Accuracy: 0.808], Valid [Loss: 0.376, Accuracy: 0.848]
# EPOCH: 30, Train [Loss: 0.419, Accuracy: 0.809], Valid [Loss: 1.375, Accuracy: 0.536]
# EPOCH: 31, Train [Loss: 0.399, Accuracy: 0.821], Valid [Loss: 0.746, Accuracy: 0.593]
# EPOCH: 32, Train [Loss: 0.404, Accuracy: 0.819], Valid [Loss: 0.434, Accuracy: 0.779]
# EPOCH: 33, Train [Loss: 0.405, Accuracy: 0.824], Valid [Loss: 0.510, Accuracy: 0.752]
# EPOCH: 34, Train [Loss: 0.402, Accuracy: 0.814], Valid [Loss: 0.466, Accuracy: 0.800]
# EPOCH: 35, Train [Loss: 0.390, Accuracy: 0.823], Valid [Loss: 0.422, Accuracy: 0.836]
# EPOCH: 36, Train [Loss: 0.399, Accuracy: 0.819], Valid [Loss: 0.422, Accuracy: 0.788]
# EPOCH: 37, Train [Loss: 0.378, Accuracy: 0.828], Valid [Loss: 0.768, Accuracy: 0.671]
# EPOCH: 38, Train [Loss: 0.385, Accuracy: 0.831], Valid [Loss: 0.462, Accuracy: 0.798]
# EPOCH: 39, Train [Loss: 0.381, Accuracy: 0.829], Valid [Loss: 0.539, Accuracy: 0.757]
# EPOCH: 40, Train [Loss: 0.378, Accuracy: 0.828], Valid [Loss: 0.332, Accuracy: 0.857]
# EPOCH: 41, Train [Loss: 0.385, Accuracy: 0.825], Valid [Loss: 0.458, Accuracy: 0.819]
# EPOCH: 42, Train [Loss: 0.359, Accuracy: 0.842], Valid [Loss: 0.355, Accuracy: 0.860]
# EPOCH: 43, Train [Loss: 0.351, Accuracy: 0.847], Valid [Loss: 0.331, Accuracy: 0.855]
# EPOCH: 44, Train [Loss: 0.370, Accuracy: 0.841], Valid [Loss: 0.864, Accuracy: 0.650]
# EPOCH: 45, Train [Loss: 0.367, Accuracy: 0.838], Valid [Loss: 0.312, Accuracy: 0.869]
# EPOCH: 46, Train [Loss: 0.355, Accuracy: 0.841], Valid [Loss: 0.343, Accuracy: 0.857]
# EPOCH: 47, Train [Loss: 0.341, Accuracy: 0.848], Valid [Loss: 0.338, Accuracy: 0.850]
# EPOCH: 48, Train [Loss: 0.336, Accuracy: 0.855], Valid [Loss: 0.454, Accuracy: 0.845]
# EPOCH: 49, Train [Loss: 0.323, Accuracy: 0.860], Valid [Loss: 0.802, Accuracy: 0.674]
# EPOCH: 50, Train [Loss: 0.329, Accuracy: 0.861], Valid [Loss: 0.313, Accuracy: 0.862]
# EPOCH: 51, Train [Loss: 0.317, Accuracy: 0.865], Valid [Loss: 0.333, Accuracy: 0.852]
# EPOCH: 52, Train [Loss: 0.309, Accuracy: 0.865], Valid [Loss: 0.765, Accuracy: 0.710]
# EPOCH: 53, Train [Loss: 0.302, Accuracy: 0.876], Valid [Loss: 0.310, Accuracy: 0.862]
# EPOCH: 54, Train [Loss: 0.308, Accuracy: 0.872], Valid [Loss: 0.360, Accuracy: 0.850]
# EPOCH: 55, Train [Loss: 0.293, Accuracy: 0.875], Valid [Loss: 0.312, Accuracy: 0.874]
# EPOCH: 56, Train [Loss: 0.290, Accuracy: 0.877], Valid [Loss: 0.562, Accuracy: 0.724]
# EPOCH: 57, Train [Loss: 0.288, Accuracy: 0.879], Valid [Loss: 0.322, Accuracy: 0.879]
# EPOCH: 58, Train [Loss: 0.279, Accuracy: 0.883], Valid [Loss: 0.262, Accuracy: 0.881]
# EPOCH: 59, Train [Loss: 0.275, Accuracy: 0.883], Valid [Loss: 0.950, Accuracy: 0.619]
# EPOCH: 60, Train [Loss: 0.275, Accuracy: 0.887], Valid [Loss: 0.307, Accuracy: 0.871]
# EPOCH: 61, Train [Loss: 0.259, Accuracy: 0.895], Valid [Loss: 0.568, Accuracy: 0.817]
# EPOCH: 62, Train [Loss: 0.256, Accuracy: 0.895], Valid [Loss: 0.321, Accuracy: 0.862]
# EPOCH: 63, Train [Loss: 0.251, Accuracy: 0.896], Valid [Loss: 0.283, Accuracy: 0.876]
# EPOCH: 64, Train [Loss: 0.260, Accuracy: 0.888], Valid [Loss: 0.369, Accuracy: 0.855]
# EPOCH: 65, Train [Loss: 0.238, Accuracy: 0.903], Valid [Loss: 0.283, Accuracy: 0.890]
# EPOCH: 66, Train [Loss: 0.237, Accuracy: 0.902], Valid [Loss: 0.282, Accuracy: 0.893]
# EPOCH: 67, Train [Loss: 0.231, Accuracy: 0.906], Valid [Loss: 0.395, Accuracy: 0.812]
# EPOCH: 68, Train [Loss: 0.225, Accuracy: 0.908], Valid [Loss: 0.299, Accuracy: 0.869]
# EPOCH: 69, Train [Loss: 0.227, Accuracy: 0.909], Valid [Loss: 0.336, Accuracy: 0.845]
# EPOCH: 70, Train [Loss: 0.228, Accuracy: 0.910], Valid [Loss: 0.369, Accuracy: 0.857]
# EPOCH: 71, Train [Loss: 0.207, Accuracy: 0.917], Valid [Loss: 0.306, Accuracy: 0.871]
# EPOCH: 72, Train [Loss: 0.215, Accuracy: 0.913], Valid [Loss: 0.345, Accuracy: 0.869]
# EPOCH: 73, Train [Loss: 0.205, Accuracy: 0.917], Valid [Loss: 0.274, Accuracy: 0.893]
# EPOCH: 74, Train [Loss: 0.219, Accuracy: 0.911], Valid [Loss: 0.315, Accuracy: 0.867]
# EPOCH: 75, Train [Loss: 0.187, Accuracy: 0.928], Valid [Loss: 0.403, Accuracy: 0.826]
# EPOCH: 76, Train [Loss: 0.192, Accuracy: 0.923], Valid [Loss: 0.285, Accuracy: 0.895]
# EPOCH: 77, Train [Loss: 0.183, Accuracy: 0.924], Valid [Loss: 0.334, Accuracy: 0.883]
# EPOCH: 78, Train [Loss: 0.199, Accuracy: 0.921], Valid [Loss: 0.316, Accuracy: 0.898]
# EPOCH: 79, Train [Loss: 0.187, Accuracy: 0.924], Valid [Loss: 0.359, Accuracy: 0.888]
# EPOCH: 80, Train [Loss: 0.176, Accuracy: 0.931], Valid [Loss: 0.319, Accuracy: 0.855]
# EPOCH: 81, Train [Loss: 0.175, Accuracy: 0.931], Valid [Loss: 0.359, Accuracy: 0.883]
# EPOCH: 82, Train [Loss: 0.158, Accuracy: 0.935], Valid [Loss: 0.310, Accuracy: 0.905]
# EPOCH: 83, Train [Loss: 0.185, Accuracy: 0.925], Valid [Loss: 0.298, Accuracy: 0.883]
# EPOCH: 84, Train [Loss: 0.151, Accuracy: 0.942], Valid [Loss: 0.428, Accuracy: 0.852]
# EPOCH: 85, Train [Loss: 0.151, Accuracy: 0.942], Valid [Loss: 0.334, Accuracy: 0.900]
# EPOCH: 86, Train [Loss: 0.160, Accuracy: 0.936], Valid [Loss: 0.383, Accuracy: 0.852]
# EPOCH: 87, Train [Loss: 0.153, Accuracy: 0.942], Valid [Loss: 0.301, Accuracy: 0.902]
# EPOCH: 88, Train [Loss: 0.147, Accuracy: 0.944], Valid [Loss: 0.467, Accuracy: 0.857]
# EPOCH: 89, Train [Loss: 0.151, Accuracy: 0.937], Valid [Loss: 0.327, Accuracy: 0.890]
# EPOCH: 90, Train [Loss: 0.131, Accuracy: 0.950], Valid [Loss: 0.348, Accuracy: 0.888]
# EPOCH: 91, Train [Loss: 0.142, Accuracy: 0.944], Valid [Loss: 0.301, Accuracy: 0.900]
# EPOCH: 92, Train [Loss: 0.124, Accuracy: 0.950], Valid [Loss: 0.337, Accuracy: 0.902]
# EPOCH: 93, Train [Loss: 0.131, Accuracy: 0.950], Valid [Loss: 0.310, Accuracy: 0.886]
# EPOCH: 94, Train [Loss: 0.124, Accuracy: 0.952], Valid [Loss: 0.481, Accuracy: 0.886]
# EPOCH: 95, Train [Loss: 0.122, Accuracy: 0.953], Valid [Loss: 0.361, Accuracy: 0.898]
# EPOCH: 96, Train [Loss: 0.111, Accuracy: 0.958], Valid [Loss: 0.315, Accuracy: 0.895]
# EPOCH: 97, Train [Loss: 0.109, Accuracy: 0.957], Valid [Loss: 0.326, Accuracy: 0.893]
# EPOCH: 98, Train [Loss: 0.113, Accuracy: 0.957], Valid [Loss: 0.435, Accuracy: 0.898]
# EPOCH: 99, Train [Loss: 0.125, Accuracy: 0.953], Valid [Loss: 0.384, Accuracy: 0.898]

# %%
# train processing plot
n_epochs = 100
epochs=range(1,n_epochs+1)
plt.ylim(0,1.0)
plt.plot(epochs,Accuracytrain,'b',label='Training accuracy')  
plt.plot(epochs, Accuracyvalid,'r',label='Validation accuracy')
plt.title('Training and Validation accuracy')
plt.legend()
plt.figure()
plt.show()

# %% [markdown]
# # 4. mask

# %%
i = 1
img = train_data[i][0].permute(1,2,0).numpy()
label = train_data[i][1]
input_tensor = train_data[i][0].unsqueeze(0).to(device)
mask, output = model(input_tensor)
y = output.argmax(1).cpu().item()
print("y is",y , "; pre is", label.item(), "=>",y==label.item())
# Out:
# y is 0 ; pre is 0 => True

# %%
plt.figure(figsize=(20,20))
plt.subplot(1,3,1)
plt.title(str(y==label)+", Real: "+str(label.item()))
plt.imshow(img)

mask = mask[0].detach().cpu().permute(1,2,0)
print('max: {:.3f}, min: {:.3f}'.format(torch.amax(mask),torch.amin(mask)))
mask = cv2.normalize(mask.numpy(), None, alpha=0,beta=1, norm_type=cv2.NORM_MINMAX)
plt.subplot(1,3,2)
plt.imshow(mask)

plt.subplot(1,3,3)
cam = show_cam_on_image(img, mask, True)
plt.imshow(cam)
# Out:
# max: 20.559, min: 0.000

# %%
for j in range(len(masklist)):
    plt.figure(figsize=(10,10))
    for i in range(masklist[j].shape[0]):
        mask = masklist[j][i].permute(1,2,0).cpu().detach().numpy()
        plt.subplot(1,4,i+1)
        plt.imshow(mask/np.amax(mask))

# %% [markdown]
# # 5. Feature map

# %%
# 定义钩子函数，获取指定层名称的特征
feature_activation = {} # 保存获取的输出
def get_activation(name):
    def hook(model, input, output):
        feature_activation[name] = output.detach()
    return hook

for name, layer in model.named_modules():
    layer.register_forward_hook(get_activation(name))
    print(name)
# Out:
# pre_layer
# pre_layer.0
# pre_layer.1
# pre_layer.2
# residual_layer
# residual_layer.0
# residual_layer.0.residualblock
# residual_layer.0.residualblock.0
# residual_layer.0.residualblock.1
# residual_layer.0.residualblock.2
# residual_layer.0.residualblock.3
# residual_layer.0.residualblock.4
# residual_layer.0.residualblock.5
# residual_layer.0.residualblock.6
# residual_layer.0.residualblock.7
# residual_layer.1
# residual_layer.1.residualblock
# residual_layer.1.residualblock.0
# residual_layer.1.residualblock.1
# residual_layer.1.residualblock.2
# residual_layer.1.residualblock.3
# residual_layer.1.residualblock.4
# residual_layer.1.residualblock.5
# residual_layer.1.residualblock.6
# residual_layer.1.residualblock.7
# residual_layer.2
# residual_layer.2.residualblock
# residual_layer.2.residualblock.0
# residual_layer.2.residualblock.1
# residual_layer.2.residualblock.2
# residual_layer.2.residualblock.3
# residual_layer.2.residualblock.4
# residual_layer.2.residualblock.5
# residual_layer.2.residualblock.6
# residual_layer.2.residualblock.7
# mask_layer
# mask_layer.0
# mask_layer.0.maskblock
# mask_layer.0.maskblock.0
# mask_layer.0.maskblock.1
# mask_layer.0.maskblock.2
# pool_layer
# pool_layer.0
# fc_layer
# fc_layer.0
# fc_layer.1
# avgpool

# %%
# for name, layer in model.named_modules():
#     bn = feature_activation[name].cpu()[0]
#     print('max: {:.3f}, min: {:.3f}'.format(torch.amax(bn),torch.amin(bn)))
#     if bn.shape[0]==10000:
#         bn = bn.reshape(100,100)
#         plt.title(name)
#         plt.imshow(bn)
#         plt.show()

# %%
key = "mask_layer"
plt.figure(figsize=(20,20))
plt.subplot(1,3,1)
plt.title(str(y==label)+", Real: "+str(label.item()))
plt.imshow(img)

mask = feature_activation[key].cpu()[0].mean(axis=0)
print('max: {:.3f}, min: {:.3f}'.format(torch.amax(mask),torch.amin(mask)))
mask = cv2.normalize(mask.numpy(), None, alpha=0,beta=1, norm_type=cv2.NORM_MINMAX)
plt.subplot(1,3,2)
plt.imshow(mask)

plt.subplot(1,3,3)
cam = show_cam_on_image(img, mask, True)
plt.imshow(cam)
# Out:
# max: 15.391, min: 0.000

# %%
# num = feature_activation[key].cpu()[0].shape[0]
# num = 10
# for i in range(num):
#     plt.figure(figsize=(10,10))
#     plt.subplot(1,3,1)
#     plt.title(y==label)
#     plt.imshow(img/np.amax(img))
    
#     bn = feature_activation[key].cpu()[0][i]
#     bn = cv2.normalize(bn.numpy(), None, alpha=0,beta=1, norm_type=cv2.NORM_MINMAX)
#     plt.subplot(1,3,2)
#     plt.title(key)
#     plt.imshow(bn)
    
#     plt.subplot(1,3,3)
#     plt.axis("off")
#     bn = cv2.merge([bn,bn,bn])
#     cam = show_cam_on_image(img, bn)
#     plt.imshow(cam)

# %%
for key in feature_activation:
    bn = feature_activation[key].cpu()
    print(key," : ",bn.shape)
# Out:
# pre_layer.0  :  torch.Size([1, 64, 100, 100])
# pre_layer.1  :  torch.Size([1, 64, 100, 100])
# pre_layer.2  :  torch.Size([1, 64, 100, 100])
# pre_layer  :  torch.Size([1, 64, 100, 100])
# residual_layer.0.residualblock.0  :  torch.Size([1, 64, 100, 100])
# residual_layer.0.residualblock.1  :  torch.Size([1, 64, 100, 100])
# residual_layer.0.residualblock.2  :  torch.Size([1, 64, 100, 100])
# residual_layer.0.residualblock.3  :  torch.Size([1, 64, 100, 100])
# residual_layer.0.residualblock.4  :  torch.Size([1, 64, 100, 100])
# residual_layer.0.residualblock.5  :  torch.Size([1, 64, 100, 100])
# residual_layer.0.residualblock.6  :  torch.Size([1, 64, 100, 100])
# residual_layer.0.residualblock.7  :  torch.Size([1, 64, 100, 100])
# residual_layer.0.residualblock  :  torch.Size([1, 64, 100, 100])
# residual_layer.0  :  torch.Size([1, 64, 100, 100])
# residual_layer.1.residualblock.0  :  torch.Size([1, 64, 100, 100])
# residual_layer.1.residualblock.1  :  torch.Size([1, 64, 100, 100])
# residual_layer.1.residualblock.2  :  torch.Size([1, 64, 100, 100])
# residual_layer.1.residualblock.3  :  torch.Size([1, 64, 100, 100])
# residual_layer.1.residualblock.4  :  torch.Size([1, 64, 100, 100])
# residual_layer.1.residualblock.5  :  torch.Size([1, 64, 100, 100])
# residual_layer.1.residualblock.6  :  torch.Size([1, 64, 100, 100])
# residual_layer.1.residualblock.7  :  torch.Size([1, 64, 100, 100])
# residual_layer.1.residualblock  :  torch.Size([1, 64, 100, 100])
# residual_layer.1  :  torch.Size([1, 64, 100, 100])
# residual_layer.2.residualblock.0  :  torch.Size([1, 64, 100, 100])
# residual_layer.2.residualblock.1  :  torch.Size([1, 64, 100, 100])
# residual_layer.2.residualblock.2  :  torch.Size([1, 64, 100, 100])
# residual_layer.2.residualblock.3  :  torch.Size([1, 64, 100, 100])
# residual_layer.2.residualblock.4  :  torch.Size([1, 64, 100, 100])
# residual_layer.2.residualblock.5  :  torch.Size([1, 64, 100, 100])
# residual_layer.2.residualblock.6  :  torch.Size([1, 64, 100, 100])
# residual_layer.2.residualblock.7  :  torch.Size([1, 64, 100, 100])
# residual_layer.2.residualblock  :  torch.Size([1, 64, 100, 100])
# residual_layer.2  :  torch.Size([1, 64, 100, 100])
# residual_layer  :  torch.Size([1, 64, 100, 100])
# mask_layer.0.maskblock.0  :  torch.Size([1, 3, 100, 100])
# mask_layer.0.maskblock.1  :  torch.Size([1, 3, 100, 100])
# mask_layer.0.maskblock.2  :  torch.Size([1, 3, 100, 100])
# mask_layer.0.maskblock  :  torch.Size([1, 3, 100, 100])
# mask_layer.0  :  torch.Size([1, 3, 100, 100])
# mask_layer  :  torch.Size([1, 3, 100, 100])
# pool_layer.0  :  torch.Size([1, 3, 10, 10])
# pool_layer  :  torch.Size([1, 3, 10, 10])
# fc_layer.0  :  torch.Size([1, 300])
# fc_layer.1  :  torch.Size([1, 2])
# fc_layer  :  torch.Size([1, 2])
#   :  torch.Size([1, 2])

# %% [markdown]
# # 5. GradCAM

# %%
from pytorch_grad_cam import GradCAM, ScoreCAM, GradCAMPlusPlus, AblationCAM, XGradCAM, EigenCAM, FullGrad
from pytorch_grad_cam.guided_backprop import GuidedBackpropReLUModel
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
from pytorch_grad_cam.utils.image import show_cam_on_image,deprocess_image,preprocess_image

def gradcams(model,input_tensor,target_layers,imgpad,optioncam):
    # GradCAM, ScoreCAM, GradCAMPlusPlus, AblationCAM, XGradCAM, EigenCAM, FullGrad
    if optioncam=="GradCAM":
        cam = GradCAM(model=model, target_layers=target_layers, use_cuda=True)
    elif optioncam=="ScoreCAM":
        cam = ScoreCAM(model=model, target_layers=target_layers, use_cuda=True)
    elif optioncam=="GradCAMPlusPlus":
        cam = GradCAMPlusPlus(model=model, target_layers=target_layers, use_cuda=True)
    elif optioncam=="AblationCAM":
        cam = AblationCAM(model=model, target_layers=target_layers, use_cuda=True)
    elif optioncam=="XGradCAM":
        cam = XGradCAM(model=model, target_layers=target_layers, use_cuda=True)
    elif optioncam=="EigenCAM":
        cam = EigenCAM(model=model, target_layers=target_layers, use_cuda=True)
    elif optioncam=="FullGrad":
        cam = FullGrad(model=model, target_layers=target_layers, use_cuda=True)
    else:
        return print("your option is not support")
    # Note: input_tensor can be a batch tensor with several images!
    # If None, returns the map for the highest scoring category. 
    # Otherwise, targets the requested index. target_index = 1
    targets = None
    # You can also pass aug_smooth=True and eigen_smooth=True, to apply smoothing.
#     grayscale_cam = cam(input_tensor=input_tensor,targets=targets,aug_smooth=True,eigen_smooth=True)
    grayscale_cam = cam(input_tensor, targets)[0]
    # In this example grayscale_cam has only one image in the batch:
    visualization = show_cam_on_image(imgpad, grayscale_cam, use_rgb=True)
    
    # Guided-GradCAM
    gb_model = GuidedBackpropReLUModel(model=model, use_cuda=True)
    gb = gb_model(input_tensor, targets)
#     if np.amax(gb)!=0:
#         gb = np.maximum(gb,0)*(1/np.amax(gb))
    cam_mask = cv2.merge([grayscale_cam, grayscale_cam, grayscale_cam])
    cam_gb = cam_mask * gb
    
    return visualization,gb,cam_gb,cam_mask

# %%
target_layers = [model.last_layer[0]]
# cam's option: GradCAM, GradCAMPlusPlus, AblationCAM, XGradCAM, EigenCAM, ScoreCAM, FullGrad
optioncam = "GradCAM"
visualization,gb,cam_gb,cam = gradcams(model,input_tensor,target_layers,img,optioncam)
print(y==label)
plt.figure(figsize=(20,20))
plt.subplot(1,4,1)
plt.imshow(cam)
plt.subplot(1,4,2)
plt.imshow(visualization)
plt.subplot(1,4,3)
plt.imshow(gb)
plt.subplot(1,4,4)
plt.imshow(cam_gb)
# Out:
# tensor(True)

# %% [markdown]
# # 99. save model

# %%
for param in model.parameters():
    param.requires_grad = True
torch.save(model,"maskFCN.pkl")
# torch.save(model.state_dict(),"maskFCN.pkl")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/10958226.1.gpu/ipykernel_148209/657967699.py in <module>
# ----> 1 for param in model.parameters():
#       2     param.requires_grad = True
#       3 torch.save(model,"maskFCN.pkl")
#       4 # torch.save(model.state_dict(),"maskFCN.pkl")
#
# AttributeError: 'collections.OrderedDict' object has no attribute 'parameters'

# %%
model = torch.load("maskNet_FCN.pkl")
